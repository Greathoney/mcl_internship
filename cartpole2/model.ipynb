# %%
import random
import gymnasium as gym # pip install gymnasium[classic-control]

import numpy as np
import tensorflow as tf 

from keras import Model
from keras.layers import Dense
from keras.optimizers import Adam
from keras.losses import mean_squared_error

# %%
class DQN(Model):
    def __init__(self):
        super(DQN, self).__init__()
        self.d1 = Dense(64, input_dim=4, activation='relu')
        self.d2 = Dense(32, activation='relu')
        self.d3 = Dense(32, activation='relu')
        self.d3 = Dense(2, activation='linear')
        self.optimizer = Adam(0.001)

        self.memory = []

    def call(self, x):
        x = self.d1(x)
        x = self.d2(x)
        y_hat = self.d3(x)
        return y_hat

# %%
def update_model(model: DQN, update_last: bool = False):

    if len(model.memory) < 1000:
        return
    
    if len(model.memory) > 10000:
        del model.memory[0]

    sample_size = 32
    batch = random.sample(model.memory, sample_size)
    if update_last:
        batch[-1] = model.memory[-1]

    states, actions, rewards, next_states, dones = zip(*batch)

    states = np.array(states)
    actions = np.array(actions)
    rewards = np.array(rewards)
    next_states = np.array(next_states)
    dones = np.array(dones)

    next_q_value = model.call(next_states).numpy() # type: ignore

    target_y = model.call(states).numpy()  # type: ignore
    target_y[range(sample_size), actions] = rewards + (1 - dones) * 0.95 * np.max(next_q_value, axis=1)  # type: ignore

    with tf.GradientTape() as tape:
        loss = mean_squared_error(target_y, model.call(states))
    grads = tape.gradient(loss, model.trainable_variables)
    model.optimizer.apply_gradients(zip(grads, model.trainable_variables))

# %%
model_left = DQN()
model_right = DQN()

model = {
    'left': model_left,
    'right': model_right
}

# 카트폴 게임 환경 생성
env = gym.make('CartPole-v1')
# env = gym.make('CartPole-v1', render_mode="human")

# %%
for episode in range(1000):
    state, info = env.reset()

    dir = np.random.choice(['left', 'right'])
    score = 0
    score_step = []

    for step in range(3000):
        action_list = model[dir].call(np.array([state])).numpy()[0]  # type: ignore

        # 확률적으로 행동을 선택
        action_list = np.exp(action_list) / np.sum(np.exp(action_list))
        action = np.random.choice([0, 1], p=action_list)

        next_state, reward, _, _, _ = env.step(action)
        done = not -0.3 < next_state[2] < 0.3

        # 각도가 크게 벌어지면 게임 오버
        if done:
            reward = -20
            model[dir].memory.append((state, action, reward, next_state, done))
            update_model(model[dir], update_last=True)
            print("Episode: {}, steps: {}, scores: {}, dir: {}, log: {}".format(episode, step, score, dir, score_step))
            break

        stable_condition = np.all(abs(np.array(next_state[1:])) < 0.1)

        # 카트가 목표 지점에 잘 도달하면 보상
        if dir == 'left' and next_state[0] < -1 and stable_condition:
            reward = 50
            model[dir].memory.append((state, action, reward, next_state, done))
            update_model(model[dir], update_last=True)
            dir = 'right'
            score += 1
            score_step.append(step)

        elif dir == 'right' and next_state[0] > 1 and stable_condition:
            reward = 50
            model[dir].memory.append((state, action, reward, next_state, done))
            update_model(model[dir], update_last=True)
            dir = 'left'
            score += 1
            score_step.append(step)

        else:
            # 보상 함수 설계
            if dir == 'left':
                if next_state[0] < -1:
                    if next_state[0] > state[0]:
                        reward = 1
                    else:
                        reward = -0.5
                else:
                    if next_state[0] < state[0]:
                        reward = 1
                    else:
                        reward = -0.5
            else:
                if next_state[0] > 1:
                    if next_state[0] < state[0]:
                        reward = 1
                    else:
                        reward = -0.5
                else:
                    if next_state[0] > state[0]:
                        reward = 1
                    else:
                        reward = -0.5

            model[dir].memory.append((state, action, reward, next_state, done))
            update_model(model[dir])

        state = next_state
# Out:
# Episode: 0, steps: 21, scores: 0
# Episode: 1, steps: 14, scores: 0
# Episode: 2, steps: 48, scores: 0
# Episode: 3, steps: 18, scores: 0
# Episode: 4, steps: 19, scores: 0
# Episode: 5, steps: 19, scores: 0
# Episode: 6, steps: 17, scores: 0
# Episode: 7, steps: 28, scores: 0
# Episode: 8, steps: 23, scores: 0
# Episode: 9, steps: 21, scores: 0
# Episode: 10, steps: 14, scores: 0
# Episode: 11, steps: 24, scores: 0
# Episode: 12, steps: 13, scores: 0
# Episode: 13, steps: 14, scores: 0
# Episode: 14, steps: 15, scores: 0
# Episode: 15, steps: 26, scores: 0
# Episode: 16, steps: 25, scores: 0
# Episode: 17, steps: 15, scores: 0
# Episode: 18, steps: 23, scores: 0
# Episode: 19, steps: 24, scores: 0
# Episode: 20, steps: 18, scores: 0
# Episode: 21, steps: 23, scores: 0
# Episode: 22, steps: 19, scores: 0
# Episode: 23, steps: 23, scores: 0
# Episode: 24, steps: 21, scores: 0
# Episode: 25, steps: 14, scores: 0
# Episode: 26, steps: 29, scores: 0
# Episode: 27, steps: 20, scores: 0
# Episode: 28, steps: 15, scores: 0
# Episode: 29, steps: 14, scores: 0
# Episode: 30, steps: 28, scores: 0
# Episode: 31, steps: 23, scores: 0
# Episode: 32, steps: 25, scores: 0
# Episode: 33, steps: 22, scores: 0
# Episode: 34, steps: 23, scores: 0
# Episode: 35, steps: 23, scores: 0
# Episode: 36, steps: 28, scores: 0
# Episode: 37, steps: 21, scores: 0
# Episode: 38, steps: 24, scores: 0
# Episode: 39, steps: 21, scores: 0
# Episode: 40, steps: 13, scores: 0
# Episode: 41, steps: 17, scores: 0
# Episode: 42, steps: 13, scores: 0
# Episode: 43, steps: 16, scores: 0
# Episode: 44, steps: 27, scores: 0
# Episode: 45, steps: 16, scores: 0
# Episode: 46, steps: 26, scores: 0
# Episode: 47, steps: 25, scores: 0
# Episode: 48, steps: 13, scores: 0
# Episode: 49, steps: 26, scores: 0
# Episode: 50, steps: 19, scores: 0
# Episode: 51, steps: 23, scores: 0
# Episode: 52, steps: 15, scores: 0
# Episode: 53, steps: 23, scores: 0
# Episode: 54, steps: 21, scores: 0
# Episode: 55, steps: 18, scores: 0
# Episode: 56, steps: 24, scores: 0
# Episode: 57, steps: 23, scores: 0
# Episode: 58, steps: 20, scores: 0
# Episode: 59, steps: 22, scores: 0
# Episode: 60, steps: 26, scores: 0
# Episode: 61, steps: 23, scores: 0
# Episode: 62, steps: 15, scores: 0
# Episode: 63, steps: 29, scores: 0
# Episode: 64, steps: 15, scores: 0
# Episode: 65, steps: 23, scores: 0
# Episode: 66, steps: 21, scores: 0
# Episode: 67, steps: 20, scores: 0
# Episode: 68, steps: 25, scores: 0
# Episode: 69, steps: 18, scores: 0
# Episode: 70, steps: 15, scores: 0
# Episode: 71, steps: 14, scores: 0
# Episode: 72, steps: 27, scores: 0
# Episode: 73, steps: 21, scores: 0
# Episode: 74, steps: 18, scores: 0
# Episode: 75, steps: 15, scores: 0
# Episode: 76, steps: 15, scores: 0
# Episode: 77, steps: 17, scores: 0
# Episode: 78, steps: 14, scores: 0
# Episode: 79, steps: 17, scores: 0
# Episode: 80, steps: 24, scores: 0
# Episode: 81, steps: 24, scores: 0
# Episode: 82, steps: 15, scores: 0
# Episode: 83, steps: 13, scores: 0
# Episode: 84, steps: 26, scores: 0
# Episode: 85, steps: 29, scores: 0
# Episode: 86, steps: 15, scores: 0
# Episode: 87, steps: 12, scores: 0
# Episode: 88, steps: 27, scores: 0
# Episode: 89, steps: 26, scores: 0
# Episode: 90, steps: 18, scores: 0
# Episode: 91, steps: 24, scores: 0
# Episode: 92, steps: 13, scores: 0
# Episode: 93, steps: 23, scores: 0
# Episode: 94, steps: 28, scores: 0
# Episode: 95, steps: 27, scores: 0
# Episode: 96, steps: 14, scores: 0
# Episode: 97, steps: 29, scores: 0
# Episode: 98, steps: 16, scores: 0
# Episode: 99, steps: 19, scores: 0
# Episode: 100, steps: 16, scores: 0
# Episode: 101, steps: 23, scores: 0
# Episode: 102, steps: 15, scores: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12968\3907616854.py in ?()
#      39             else:
#      40                 reward += np.clip(next_state[0], 0, 1)
#      41
#      42             model[cart_goal].memory.append((state, action, reward, next_state, done))
# ---> 43             update_model(model[cart_goal])
#      44
#      45         state = next_state
#      46
#
# ~\AppData\Local\Temp\ipykernel_12968\417278726.py in ?(model, update_last)
#      23     target_y[range(sample_size), actions] = rewards + (1 - dones) * 0.95 * np.max(next_q_value, axis=1)  # type: ignore
#      24
#      25     with tf.GradientTape() as tape:
#      26         loss = tf.reduce_mean(tf.square(target_y - model.call(states)))
# ---> 27     grads = tape.gradient(loss, model.trainable_variables)
#      28     model.optimizer.apply_gradients(zip(grads, model.trainable_variables))
#
# c:\Users\honey\anaconda3\envs\frequency\lib\site-packages\tensorflow\python\eager\backprop.py in ?(self, target, sources, output_gradients, unconnected_gradients)
#    1059               output_gradients))
#    1060       output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1061                           for x in output_gradients]
#    1062
# -> 1063     flat_grad = imperative_grad.imperative_grad(
#    1064         self._tape,
#    1065         flat_targets,
#    1066         flat_sources,
#
# c:\Users\honey\anaconda3\envs\frequency\lib\site-packages\tensorflow\python\eager\imperative_grad.py in ?(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63   except ValueError:
#      64     raise ValueError(
#      65         "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
#      66
# ---> 67   return pywrap_tfe.TFE_Py_TapeGradient(
#      68       tape._tape,  # pylint: disable=protected-access
#      69       target,
#      70       sources,
#
# c:\Users\honey\anaconda3\envs\frequency\lib\site-packages\tensorflow\python\eager\backprop.py in ?(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     142     gradient_name_scope = "gradient_tape/"
#     143     if forward_pass_name_scope:
#     144       gradient_name_scope += forward_pass_name_scope + "/"
#     145     with ops.name_scope(gradient_name_scope):
# --> 146       return grad_fn(mock_op, *out_grads)
#     147   else:
#     148     return grad_fn(mock_op, *out_grads)
#
# c:\Users\honey\anaconda3\envs\frequency\lib\site-packages\tensorflow\python\ops\nn_grad.py in ?(op, grad_softmax)
#     299
#     300   """
#     301   softmax = op.outputs[0]
#     302   sum_channels = math_ops.reduce_sum(grad_softmax * softmax, -1, keepdims=True)
# --> 303   return (grad_softmax - sum_channels) * softmax
#
# c:\Users\honey\anaconda3\envs\frequency\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\honey\anaconda3\envs\frequency\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y)
#    1456         # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1457         #   r_binary_op_wrapper use different force_same_dtype values.
#    1458         x, y = maybe_promote_tensors(x, y)
#    1459         return func(x, y, name=name)
# -> 1460       except (TypeError, ValueError) as e:
#    1461         # Even if dispatching the op failed, the RHS may be a tensor aware
#    1462         # object that can implement the operator with knowledge of itself
#    1463         # and the tensor.
#
# c:\Users\honey\anaconda3\envs\frequency\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#    1815     new_vals = gen_sparse_ops.sparse_dense_cwise_mul(y.indices, y.values,
#    1816                                                      y.dense_shape, x, name)
#    1817     return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1818   else:
# -> 1819     return multiply(x, y, name=name)
#
# c:\Users\honey\anaconda3\envs\frequency\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\honey\anaconda3\envs\frequency\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1173
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
#    1176         return dispatch_target(*args, **kwargs)
# -> 1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179         # TypeError, when given unexpected types.  So we need to catch both.
#    1180         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Users\honey\anaconda3\envs\frequency\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#     526
#     527    * InvalidArgumentError: When `x` and `y` have incompatible shapes or types.
#     528   """
#     529
# --> 530   return gen_math_ops.mul(x, y, name)
#
# c:\Users\honey\anaconda3\envs\frequency\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(x, y, name)
#    7325         _ctx, "Mul", name, x, y)
#    7326       return _result
#    7327     except _core._NotOkStatusException as e:
#    7328       _ops.raise_from_not_ok_status(e, name)
# -> 7329     except _core._FallbackException:
#    7330       pass
#    7331     try:
#    7332       return mul_eager_fallback(
#
# KeyboardInterrupt:
